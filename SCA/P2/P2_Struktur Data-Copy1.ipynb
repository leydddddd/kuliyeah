# %%
import math as meth
import gym
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 import math as meth
# ----> 2 import gym
#
# ModuleNotFoundError: No module named 'gym'

# %%
meth.sqrt(100)
# Out:
# 10.0
