# %%
from math import sqrt

# %%
import math as meth

# %%
from math import *

# %%
sqrt(100)
# Out:
# 10.0

# %%
meth.sqrt(100)
# Out:
# 10.0

# %%
help(sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.
